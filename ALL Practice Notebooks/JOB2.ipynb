# %%
#dbutils.widgets.text("JOB2_File_Name","finance_data.json")

# %%
param_filename=dbutils.widgets.get("JOB2_File_Name")
print(param_filename)
df_json=spark.read.json(f"/mnt/azurestorage0912/firstcontainer/{param_filename}").limit(10)
#df_multi_col=df_json.select("Age","Name","PassengerId").limit(10)
#display(df_multi_col)
display(df_json)
