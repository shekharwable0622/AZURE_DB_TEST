# %%
spark.sql("create database if not exists PipelineDB")

# %%
df_jsondelta=spark.read.json("/mnt/azurestorage0912/firstcontainer/output.json")
df_jsondelta.write.mode("overwrite").format("delta").saveAsTable("PipelineDB.delta_table")

# %%
printcount=spark.read.format("delta").table("PipelineDB.delta_table").count()
print(printcount)
