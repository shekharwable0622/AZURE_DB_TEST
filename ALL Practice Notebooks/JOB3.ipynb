# %%
#dbutils.widgets.text("JOB3_Table_Name","TestDB.delta_table")

# %%
import pyspark.sql.functions as F
param_table_name=dbutils.widgets.get("JOB3_Table_Name")
print(param_table_name)
dffire=spark.read.format("delta").table(param_table_name)#(f"{param_filename}")#(""+param_table_name) #
#display(dffire)
sumof_call=dffire.agg(F.sum("call_number")).alias("Total Calls")
display(sumof_call)
